# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# package.csv linear regression and polynomial.csv polynomial regression follow kore

# %%
dataset = pd.read_csv('package.csv')
dataset.head()
# Out:
#    CGPA  Package
# 0  8.00     6.68
# 1  7.36     5.82
# 2  8.15     7.27
# 3  9.02     8.56
# 4  7.27     4.72

# %%
# dataset = pd.read_csv('polynomial.csv')
# dataset.head()

# %%
sns.scatterplot(x='CGPA', y='Package', data=dataset,)
plt.show()

# %%
x = dataset[['CGPA']]
y = dataset['Package']

# %%
# [[]] karon holo scaling korte hole 2D data dorkar hoy.tai [[]] dia 1D ke 2D kora holo

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
sc.fit(x)
x = pd.DataFrame(sc.transform(x), columns=x.columns)

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.2,random_state=42)

# %%
# ['linear', 'poly', 'rbf', 'sigmoid', 'precomputed']

# %%
from sklearn.svm import SVR
svr = SVR(kernel='linear',degree=3)
svr.fit(x_train,y_train)
# Out:
# SVR(kernel='linear')

# %%
svr.score(x_test,y_test)*100,svr.score(x_train,y_train)*100
# Out:
# (88.4879624714772, 89.62596419544242)

# %%
#(88.4879624714772, 89.62596419544242) for linear regression

# %%
# x,y

# %%
svr.predict([[-1.189458]])
# Out:
# C:\Users\USER\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# array([4.20951201])

# %%
sns.scatterplot(x='CGPA',y='Package',data=dataset)
plt.plot(dataset['CGPA'],svr.predict(x),color='red')
plt.show()
