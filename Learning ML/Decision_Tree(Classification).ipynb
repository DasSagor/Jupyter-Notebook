# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.plotting import plot_decision_regions

# %%
dataset = pd.read_csv('Social_Network_Ads.csv')
dataset.head()
# Out:
#    Age  Estimated_salary  Purchased
# 0   56            122455          1
# 1   46            108179          1
# 2   32             60714          0
# 3   25            117946          0
# 4   38            124616          1

# %%
sns.scatterplot(x='Age',y='Estimated_salary',hue='Purchased',data=dataset)
plt.show()

# %%
x = dataset.iloc[:,:-1]
y = dataset['Purchased']

# %%
# Age and Estimated_salary ke scalling korte hobe.

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(x)
x = pd.DataFrame(sc.transform(x),columns=x.columns)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt1 = DecisionTreeClassifier(criterion='entropy')
dt1.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
dt.score(x_test,y_test)*100
# Out:
# 83.33333333333334

# %%
dt1.score(x_test,y_test)*100
# Out:
# 83.33333333333334

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=dt)
plt.show()
# Out:
# C:\Users\USER\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=dt1)
plt.show()
# Out:
# C:\Users\USER\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
dt.predict([[32,60714]])
# Out:
# C:\Users\USER\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
dt1.predict([[32,60714]])
# Out:
# C:\Users\USER\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(40,40))
plot_tree(dt1)
# plt.savefig('demo.png')
plt.show()
