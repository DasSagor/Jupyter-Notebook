# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
dataset = pd.read_csv('age_salary_experience.csv')
dataset.head(5)
# Out:
#    Age  Experience (Years)  Salary (LPA)
# 0   59                  21         14.16
# 1   49                  16         11.29
# 2   35                   9          7.62
# 3   28                   3          4.63
# 4   41                   9          6.99

# %%
dataset.shape
# Out:
# (200, 3)

# %%
dataset.isnull().sum()
# Out:
# Age                   0
# Experience (Years)    0
# Salary (LPA)          0
# dtype: int64

# %%
sns.pairplot(data=dataset)
plt.show()

# %%
sns.heatmap(dataset.corr(), annot=True)
plt.show()

# %%
x = dataset.iloc[:, :-1]
y = dataset['Salary (LPA)']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test, y_test)*100
# Out:
# 93.49828359258517

# %%
lr.predict(x_test)
# Out:
# array([ 2.88640796,  9.90899587,  4.75975001, 12.42195679,  9.5297277 ,
#         9.96380654,  8.91751417,  3.78197098,  2.30159976,  3.34789213,
#         6.37714791,  3.27937879, 11.5126911 ,  8.48343532, 12.49047013,
#        14.02565202, 10.00491454, 10.46639872,  2.77678661, 14.55564954,
#        10.53491207,  2.30159976,  8.97232484, 10.48010139,  5.31715287,
#         5.3445582 ,  9.9364012 ,  7.96714047, 15.03083639,  6.87974009,
#         6.82492942, 11.48528576,  2.3290051 , 11.47158309, 12.5041728 ,
#        13.57787051,  5.87455572,  3.34789213, 11.5126911 ,  7.85751913])
