# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('binary_polynomial_dataset.csv')
dataset.head()
# Out:
#       data1     data2  output
# 0 -2.509198 -8.966366       1
# 1  9.014286  0.627093       0
# 2  4.639879  0.812702       0
# 3  1.973170  2.748598       0
# 4 -6.879627  4.521827       0

# %%
sns.scatterplot(x='data1', y='data2', hue='output', data=dataset)
plt.show()

# %%
x = dataset.iloc[:,:-1]
y = dataset['output']

# %% [markdown]
# # 1st a simple classification kore dekbo j accuracy koto and sothik vabe classified korte parce kina

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
model1 = LogisticRegression()
model1.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
model1.score(x_test, y_test)*100
# Out:
# 31.666666666666664

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.to_numpy(), y.to_numpy(), clf=model1, legend=2)
plt.show()
# Out:
# C:\Users\USER\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # dekha jacce j accuracy onk kom and sothik vabe classified korte parce na. Tai akhon Polynomial classified use korte hobe and accuracy and sothik vabe classified korte parce kina dekhte hobe.

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=2)
x_poly = poly.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train_1, x_test_1, y_train_1, y_test_1 = train_test_split(x_poly, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
model2 = LogisticRegression()
model2.fit(x_train_1, y_train_1)
# Out:
# LogisticRegression()

# %%
model2.score(x_test_1, y_test_1)*100
# Out:
# 96.66666666666667
