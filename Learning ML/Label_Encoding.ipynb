# %%
import pandas as pd

# %%
df = pd.DataFrame({'name':['Sagor','Shuvo','Menoti','Endrojit','Prionty']})
df
# Out:
#        name
# 0     Sagor
# 1     Shuvo
# 2    Menoti
# 3  Endrojit
# 4   Prionty

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['en_name']=le.fit_transform(df['name'])
df
# Out:
#        name  en_name
# 0     Sagor        3
# 1     Shuvo        4
# 2    Menoti        1
# 3  Endrojit        0
# 4   Prionty        2

# %%
dataset = pd.read_csv('loan_application.csv')
dataset.head(23)
# Out:
#      Load_ID          Name  Gender Married Dependent     Education  \
# 0   LP100000   Applicant_0    Male     Yes         1  Not Graduate
# 1   LP100001   Applicant_1    Male     Yes        3+      Graduate
# 2   LP100002   Applicant_2  Female     Yes         1      Graduate
# 3   LP100003   Applicant_3    Male     Yes         1           NaN
# 4   LP100004   Applicant_4    Male      No         2  Not Graduate
# 5   LP100005   Applicant_5    Male     Yes       NaN  Not Graduate
# 6   LP100006   Applicant_6    Male     Yes        3+      Graduate
# 7   LP100007   Applicant_7    Male     Yes         0  Not Graduate
# 8   LP100008   Applicant_8  Female     Yes       NaN           NaN
# 9   LP100009   Applicant_9    Male     NaN        3+  Not Graduate
# 10  LP100010  Applicant_10     NaN     Yes         1      Graduate
# 11  LP100011  Applicant_11    Male     Yes        3+      Graduate
# 12  LP100012  Applicant_12    Male      No         1      Graduate
# ...

# %%
dataset['Property_Area'].unique()
# Out:
# array(['Urban', 'Rural', nan, 'Semiurban'], dtype=object)

# %%
la = LabelEncoder()
la.fit(dataset['Property_Area'])
# Out:
# LabelEncoder()

# %%
la.transform(dataset['Property_Area'])
# Out:
# array([2, 0, 0, 2, 3, 0, 2, 2, 0, 0, 1, 2, 0, 0, 0, 1, 1, 3, 2, 2, 2, 3,
#        2, 3, 0, 2, 0, 0, 2, 0, 0, 1, 0, 3, 1, 3, 0, 2, 0, 3, 2, 1, 2, 0,
#        2, 1, 2, 0, 1, 2, 1, 0, 2, 0, 0, 0, 2, 2, 2, 2, 1, 0, 0, 0, 1, 2,
#        2, 2, 2, 0, 0, 2, 0, 1, 3, 0, 1, 2, 1, 0, 2, 2, 2, 0, 0, 0, 2, 2,
#        0, 0, 0, 0, 1, 1, 2, 1, 0, 0, 1, 1, 0, 2, 1, 1, 2, 2, 1, 1, 1, 1,
#        2, 0, 1, 1, 1, 1, 1, 0, 2, 2, 0, 2, 0, 0, 2, 1, 0, 0, 1, 1, 2, 0,
#        2, 1, 0, 3, 1, 2, 2, 2, 1, 2, 3, 1, 1, 2, 1, 0, 2, 0, 2, 2, 3, 1,
#        2, 0, 0, 2, 0, 0, 1, 2, 1, 0, 1, 0, 0, 0, 0, 0, 1, 0, 1, 0, 2, 2,
#        0, 0, 3, 2, 1, 1, 2, 1, 0, 0, 0, 1, 1, 1, 0, 1, 3, 1, 1, 2, 2, 2,
#        2, 1, 2, 3, 0, 2, 0, 1, 1, 1, 2, 1, 0, 1, 1, 2, 1, 0, 0, 2, 2, 0,
#        1, 0, 2, 2, 0, 2, 0, 0, 0, 1, 1, 1, 0, 2, 0, 3, 1, 0, 0, 1, 0, 0,
#        3, 1, 3, 2, 0, 2, 2, 2, 3, 0, 1, 1, 1, 3, 0, 2, 1, 0, 2, 1, 3, 2,
#        1, 1, 0, 2, 1, 0, 2, 1, 0, 1, 2, 0, 0, 1, 2, 0, 2, 2, 1, 2, 1, 2,
# ...

# %%
dataset['le_Property_Area'] = la.transform(dataset['Property_Area'])
dataset.head(23)
# Out:
#      Load_ID          Name  Gender Married Dependent     Education  \
# 0   LP100000   Applicant_0    Male     Yes         1  Not Graduate
# 1   LP100001   Applicant_1    Male     Yes        3+      Graduate
# 2   LP100002   Applicant_2  Female     Yes         1      Graduate
# 3   LP100003   Applicant_3    Male     Yes         1           NaN
# 4   LP100004   Applicant_4    Male      No         2  Not Graduate
# 5   LP100005   Applicant_5    Male     Yes       NaN  Not Graduate
# 6   LP100006   Applicant_6    Male     Yes        3+      Graduate
# 7   LP100007   Applicant_7    Male     Yes         0  Not Graduate
# 8   LP100008   Applicant_8  Female     Yes       NaN           NaN
# 9   LP100009   Applicant_9    Male     NaN        3+  Not Graduate
# 10  LP100010  Applicant_10     NaN     Yes         1      Graduate
# 11  LP100011  Applicant_11    Male     Yes        3+      Graduate
# 12  LP100012  Applicant_12    Male      No         1      Graduate
# ...
